# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from mypriceplotter import plot_prices

# %% [markdown]
# Always seed random numbers

# %%
np.random.seed(42)
times = np.arange(1,1001)
prices = np.random.randint(75,100) + np.array([np.random.randint(-20,20) for _ in range(1000)]).cumsum()

# %%
plt.plot(prices)
